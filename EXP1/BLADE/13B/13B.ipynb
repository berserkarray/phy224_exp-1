# %% [markdown]
# apparatus was set up on a meter strip. the following quatities are measured from the distance of phone which was at 0
# phone = 0
# Lazer = 60
# blade = 13
# polarizer = 44
# so distance b/w blade and lazer = 60-13 = 47

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Raw Data.csv")
df.head()
# Out:
#    Time (s)  Illuminance (lx)
# 0      78.9              63.0
# 1      79.1              62.0
# 2      79.3              63.0
# 3      81.1              64.0
# 4      83.9              63.0

# %%
x = df["Time (s)"]

# %%
y = df["Illuminance (lx)"]

# %%
plt.plot(x,y)

# %%
df
# Out:
#     Time (s)  Illuminance (lx)
# 0       78.9              63.0
# 1       79.1              62.0
# 2       79.3              63.0
# 3       81.1              64.0
# 4       83.9              63.0
# 5       84.9              62.0
# 6       85.1              61.0
# 7       85.5              60.0
# 8       86.1              59.0
# 9       86.3              58.0
# 10      86.5              57.0
# 11      86.9              56.0
# 12      87.3              55.0
# 13      88.1              54.0
# 14      89.6              53.0
# 15      89.8              52.0
# 16      90.0              51.0
# 17      90.4              50.0
# 18      91.0              49.0
# 19      91.8              48.0
# 20      92.0              45.0
# 21      92.2              42.0
# 22      92.4              41.0
# 23      92.8              39.0
# 24      93.0              36.0
# 25      93.2              34.0
# 26      93.4              33.0
# 27      93.6              31.0
# 28      93.8              28.0
# ...

# %% [markdown]
# max at 81.1 = 64
# 90% of 64 = 57.6 at 86.4
# 10% of 64 = 6.4 at 115.5
# time difference = 29.1
# w(z) for this dataset = 0.03(rough estimate)*29.1 i.e 0.873
