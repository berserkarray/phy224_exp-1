# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("Raw Data.csv")
df.head()
# Out:
#    Time (s)  Illuminance (lx)
# 0  0.175133             347.0
# 1  0.375131             364.0
# 2  0.575130             368.0
# 3  0.775136             369.0
# 4  0.975131             373.0

# %%
x = df["Time (s)"]
y = df["Illuminance (lx)"]
plt.plot(x,y)

# %%
df_15 = pd.read_csv("15.csv")
x_15 = df_15["Time (s)"]
y_15 = df_15["Illuminance (lx)"]
plt.plot(x_15,y_15)

# %% [markdown]
# max at 279 which is at 183.05......90% of 279 is 251 which is at 235.86.....10% of 279 is 27.9  which is at 261.2....w(z) = 0.03*( 261.2 - 235.86) = 0.76

# %%
df_16 = pd.read_csv("16.csv")
x_16 = df_16["Time (s)"]
y_16 = df_16["Illuminance (lx)"]
plt.plot(x_16,y_16)

# %% [markdown]
# max is 274 at 400.1 ............. 90% of 274 = 246.6 which is at 426.4 .......... 10% of 274 = 27.4 which is at 459.99 .......... so w(z) = 0.023*33.59 =  0.07725

# %%
df_17 = pd.read_csv("17.csv")
x_17 = df_17["Time (s)"]
y_17 = df_17["Illuminance (lx)"]
plt.plot(x_17,y_17)

# %% [markdown]
# max is 192 which is at 1091.889 ........ 90% of 192 = 172.8 which is at 1084.1 .......... 10% of 192 = 19.2 which is at 1151.2 ....... so w(z) =0.012*(1151.2-1084.1) = 0.8
