# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("Raw Data.csv")
df.head()
# Out:
#    Time (s)  Illuminance (lx)
# 0  0.172598              29.0
# 1  0.372598              36.0
# 2  0.572598              38.0
# 3  0.772598              39.0
# 4  0.972645              41.0

# %%
x = df["Time (s)"]
y = df["Illuminance (lx)"]
plt.plot(x,y)

# %%
df_20 = pd.read_csv("20.csv")
x_20 = df_20["Time (s)"]
y_20 = df_20["Illuminance (lx)"]
plt.plot(x_20,y_20)

# %% [markdown]
# max at 80 which is at 322.8 ...... 90% of 80 is 72 which is at 329.6 ....... 10% of 80 = 8 which is at 357.4 ........ so w(z) = 0.03*27.8 = 0.834

# %%
df_21 = pd.read_csv("21.csv")
x_21 = df_21["Time (s)"]
y_21 = df_21["Illuminance (lx)"]
plt.plot(x_21,y_21)

# %% [markdown]
# max is 96 ....... 90% of 96 is 86.4 which is at 564.9 ........ 10% of 96 is 9.6 which is at 581.15 .......... so w(z) = 0.05*16.25 = 8.125

# %%
df_22 = pd.read_csv("22.csv")
x_22 = df_22["Time (s)"]
y_22 = df_22["Illuminance (lx)"]
plt.plot(x_22,y_22)

# %% [markdown]
# max at 101 ........ so 90% of 101 = 90.9 which is at 714.2 ......... and 10% of 101 = 10.1 which is at 724.7 .......... so w(z) = 0.07*(724.7-714.2) = 0.735
